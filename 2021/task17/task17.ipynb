# %% [markdown]
# Рассматривается множество целых чисел, принадлежащих числовому отрезку [5883; 15906], которые делятся на 9 или 23 и не делятся на 13, 18, 19, 22. Найдите количество таких чисел и максимальное из них. В ответе запишите два целых числа без пробелов и других дополнительных символов: сначала количество, затем максимальное число.

# %%
a = 5883
b = 15906
c = 0
for i in range(a, b + 1):
  if (i % 9 == 0 or i % 23 == 0) and i % 13 != 0 and i % 18 != 0 and i % 19 != 0 and i % 22 != 0:
    c += 1
    print(c, i)
# Out:
# 1 5888
# 2 5895
# 3 5911
# 4 5913
# 5 5931
# 6 5934
# 7 5949
# 8 5957
# 9 6003
# 10 6021
# 11 6026
# 12 6039
# 13 6049
# 14 6057
# 15 6075
# 16 6093
# 17 6095
# 18 6111
# 19 6129
# 20 6141
# 21 6147
# 22 6164
# 23 6165
# 24 6183
# 25 6187
# 26 6219
# 27 6233
# 28 6237
# 29 6255
# 30 6256
# 31 6273
# 32 6291
# 33 6302
# 34 6309
# 35 6325
# 36 6345
# 37 6348
# 38 6363
# 39 6371
# 40 6381
# 41 6394
# 42 6399
# 43 6417
# 44 6440
# 45 6453
# 46 6463
# 47 6471
# 48 6486
# 49 6489
# 50 6507
# 51 6509
# 52 6525
# 53 6532
# 54 6543
# 55 6561
# 56 6579
# 57 6597
# 58 6601
# 59 6615
# 60 6633
# 61 6647
# 62 6651
# 63 6670
# 64 6687
# 65 6693
# 66 6705
# 67 6716
# 68 6723
# 69 6739
# 70 6741
# 71 6759
# 72 6762
# 73 6777
# 74 6785
# 75 6795
# 76 6808
# 77 6813
# 78 6831
# 79 6849
# 80 6854
# 81 6867
# 82 6885
# 83 6900
# 84 6921
# 85 6923
# 86 6939
# 87 6946
# 88 6957
# 89 6969
# 90 6975
# 91 6993
# 92 7015
# 93 7029
# 94 7047
# 95 7061
# 96 7065
# 97 7083
# 98 7101
# 99 7107
# 100 7119
# ...

# %%
a = 5883
b = 15906
for i in range(a, b + 1):
  if i % 9 == 0 or i % 23 == 0 and i % 13 != 0 and i % 18 != 0 and i % 19 != 0 and i % 22 != 0:
    print(i)

# %% [markdown]
# Рассматривается множество целых чисел, принадлежащих числовому отрезку [5913; 11753], которые делятся на 5 и 11 и не делятся на 7, 10, 13, 22. Найдите количество таких чисел и минимальное из них. В ответе запишите два целых числа без пробелов и других дополнительных символов: сначала количество, затем минимальное число.

# %%
a, b, c, d = 5913, 11753, 0, 0
for i in range(a, b + 1):
  x = []
  if (i % 5 == 0 and i % 11 == 0) and i % 7 != 0 and i % 10 != 0 and i % 13 != 0 and i % 22 != 0:
    x.append(i)
    print(i)
# Out:
# 5995
# 6105
# 6215
# 6325
# 6655
# 6765
# 6875
# 6985
# 7095
# 7205
# 7425
# 7535
# 7645
# 7755
# 7975
# 8195
# 8305
# 8415
# 8525
# 8635
# 8745
# 8965
# 9075
# 9185
# 9405
# 9515
# 9735
# 9845
# 9955
# 10065
# 10175
# 10285
# 10505
# 10615
# 10835
# 10945
# 11055
# 11275
# 11385
# 11495
# 11605
# 11715

# %%
# %%time
a, b, c, d, e = 5913, 11753, 0, 20000, 20000
x = []
for i in range(a, b + 1):
  if (i % 5 == 0 and i % 11 == 0) and i % 7 != 0 and i % 10 != 0 and i % 13 != 0 and i % 22 != 0:
    x.append(i)
    if i < e: e = i
    d = min(d, i)
    c += 1
print((len(x), c), (e, min(x), d))
# Out:
# (42, 42) (5995, 5995, 5995)
# CPU times: user 2.67 ms, sys: 0 ns, total: 2.67 ms
# Wall time: 2.55 ms

# %%
# %%time
a, b, c, d, e = 5913, 11753, 0, 20000, 20000
while a % 55 != 0:
  a += 1

x = []
for i in range(a, b + 1, 55):
  if i % 7 != 0 and i % 10 != 0 and i % 13 != 0 and i % 22 != 0:

    x.append(i)
    if i < e: e = i
    d = min(d, i)
    c += 1
print((len(x), c), (e, min(x), d))
# Out:
# (42, 42) (5995, 5995, 5995)
# CPU times: user 250 µs, sys: 4 µs, total: 254 µs
# Wall time: 203 µs

# %% [markdown]
# Определите количество принадлежащих отрезку $[2 · 10^{10}; 4 · 10^{10}]$ натуральных чисел, которые делятся на 7 и на 100 000 и при этом не делятся на 13, 29, 43 и 101, а также наименьшее из таких чисел. В ответе запишите два целых числа без пробелов и других дополнительных символов: сначала количество, затем наименьшее число.

# %%
# %%time
a, b = 2 * (10 ** 10), 4 * (10 ** 10)
x = []
while a % 700000 != 0:
  a += 1
c = 0
for i in range(a, b + 1, 700000):
  if i % 13 != 0 and i % 29 != 0 and i % 43 != 0 and i % 101 != 0:
    x.append(i)
print(len(x), min(x))
# Out:
# 24626 20000400000
# CPU times: user 102 ms, sys: 2.97 ms, total: 105 ms
# Wall time: 106 ms

# %%
# %%time
a, b = 2 * (10 ** 10), 4 * (10 ** 10)
x = []
c = 0
for i in range(a, b + 1, 100000):
  if i % 7 == 0 and i % 13 != 0 and i % 29 != 0 and i % 43 != 0 and i % 101 != 0:
    x.append(i)
print(len(x), min(x))
# Out:
# 24626 20000400000
# CPU times: user 51.3 ms, sys: 2 ms, total: 53.3 ms
# Wall time: 53.7 ms

# %% [markdown]
# Назовём натуральное число подходящим, если ровно два из его делителей входят в список (11, 13, 17, 19). Определите количество подходящих чисел, принадлежащих отрезку [22 000; 33 000], а также наименьшее из таких чисел. В ответе запишите два целых числа: сначала количество, затем, без разделительных знаков, наименьшее число.

# %%
a = 22000
b = 33000
c = 0
d = 40000
for i in range(a, b + 1):
  x = []
  for n in [11, 13, 17, 19]:
    if i % n == 0:
      x.append(n)
  if len(x) == 2:
    c += 1
    if i < d: d = i
print(c, d)
# Out:
# 277 22022

# %%
20*10**9 // 700000
# Out:
# 28571

# %%
bin(98)
# Out:
# '0b1100010'

# %%
bin(98)[2:]
# Out:
# '1100010'

# %%
bin(98)[2:][::-1]
# Out:
# '0100011'

# %%
# %%time
m = 0
n = 0
a, b = 2*10**10, 4*10**10

while a % 100000: 
    a += 1

for i in range(a, b + 1, 100000):
    # if i % 10000000 == 0: print(i)
    if (i % 7 == 0 and i % 100000 == 0) and i % 13 != 0 and i % 29 != 0 and i % 43 != 0 and i % 101 != 0:
        n += 1
        if m == 0:
            m = i
print(n, m, sep = " ")
# Out:
# 24626 20000400000
# CPU times: user 52.8 ms, sys: 1.24 ms, total: 54.1 ms
# Wall time: 56.2 ms

# %%
# %%time
m = 0
n = 0
a, b = 2*10**10+400000, 4*10**10

while a % 700000: 
    a += 1

for i in range(a, b + 1, 700000):
    # if i % 10000000 == 0: print(i)
    if (i % 7 == 0 and i % 100000 == 0) and i % 13 != 0 and i % 29 != 0 and i % 43 != 0 and i % 101 != 0:
        n += 1
        if m == 0:
            m = i
print(n, m, sep = " ")
# Out:
# 24626 20000400000
# CPU times: user 26.7 ms, sys: 0 ns, total: 26.7 ms
# Wall time: 28.9 ms
