# %% [markdown]
# # Задание 10

# %% [markdown]
# С осторожностью относиться к параметру `Все словоформы`

# %% [markdown]
# Скачайте текст [отсюда](https://hpmor.ru/files/hpmor_ru.html)

# %% [markdown]
# унитарность

# %% [markdown]
# залетел

# %% [markdown]
# грязнокровка

# %% [markdown]
# биологические

# %% [markdown]
# Слизерин - слизерин
