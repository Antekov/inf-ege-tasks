# %% [markdown]
# # Задание 25. Тренировка

# %% [markdown]
# Среди задач можно выделить следующие типы:
# - **Дополнить** код &mdash; даётся шаблон кода, в котором нет ошибок (преднамеренных), но не хватает какой-то части. Эту часть необходимо дописать, чтобы код решал поставленную перед ним задачу.
# - **Исправить** код &mdash; даётся шаблон кода, в котором возможны ошибки (преднамеренные), но всё необходимое для решения поставленной перед кодом задачи присутствует. Необходимо исправить ошибки, чтобы код решал поставленную перед ним задачу.
# - **Написать** код &mdash; даётся шаблон кода (возмжно, пустой), который нужно доработать любым способом, чтобы он решал поставленную перед ним задачу.
# - **Ответить** на вопрос по коду &mdash; даётся шаблон кода или задача, которую код должен решать. Необходимо ответить на какой-то вопрос про код или задачу.
#
# В некоторых задачах в коде будет встречаться команда `pass`, которая добавлена только для того, чтобы незавершенный код не приводил к ошибке при запуске ячейки. При решении все такие команды надо удалить.

# %% [markdown]
# ## Задача 1
#
# Вам необходимо решить задачу:
#
# Найдите количество чисел на отрезке от $[3418, 5228]$, у которых ровно $4$ делителя.
#
# У вас есть такой незаконченный код, который требуется *дополнить*, чтобы он находил решение.

# %%
a, b = 3418, 5228

answer = 0

for n in range(a, b + 1):
    count = 0
    for d in range(1, n + 1):
        if n % d == 0:
            count += 1
# TODO: add your code below

# %% [markdown]
# ## Задача 2
#
# Вам необходимо решить задачу:
#
# Найдите количество чисел на отрезке от $[3418, 5228]$, у которых ровно $6$ делителей.
#
# У вас есть такой незаконченный код, который требуется *дополнить*, чтобы он находил решение.

# %%
c = 0

for n in range(3418, 5229):
    divisors = []
    for d in range(1, n + 1):
        if n % d == 0:
            pass
# TODO: add your code below
# Out:
# 0

# %%
#@title Текст заголовка по умолчанию { run: "auto", vertical-output: true, display-mode: "both" }
a =  3418#@param {type:"integer"}
b =  5228#@param {type:"integer"}
C =  6#@param {type:"integer"}

answer = 0

for n in range(a, b + 1):
  count = 0
  for d in range(1, n + 1):
    if n % d == 0:
      count += 1
  if count == C:
    answer += 1

print(answer)
# Out:
# 137

# %% [markdown]
# Count до цикла
#
# d1 d2 в цикле до n+1
#
# ошибка в диапазоне

# %%
2*1000*10*0.04**3
# Out:
# 1.2800000000000002

# %%
700*5*0.04**3*10 + 10**5*0.04**2 - 1.28
# Out:
# 160.96
